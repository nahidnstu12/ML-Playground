# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# !pip install pandas_datareader
# from pandas_datareader import data as web

# %%
# df = web.DataReader('AAPL', data_source='yahoo',start='2012-01-01', end='2019-12-31')
# df

# %%
dataset = pd.read_csv('../.txt')

# %%
print(df.shape)
# Out:
# (2012, 6)

# %%
# visualize the closing price history
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.show()

# %%
# create new dataframe only closing price
data = df.filter(['Close'])

dataset = data.values
# get the number of rows to train model
training_data_len =math.ceil( len(dataset)* 0.8)

training_data_len
# Out:
# 1610

# %%
# scal data -preprocessing for NN
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.01243228],
#        [0.01375958],
#        [0.01651631],
#        ...,
#        [0.98381398],
#        [0.99104513],
#        [1.        ]])

# %%
# create training dataset
# create scaled traing dataset
train_data = scaled_data[0:training_data_len,:]
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    if i<= 62:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.01243228, 0.01375958, 0.01651631, 0.01914091, 0.01873851,
#        0.0196454 , 0.01923099, 0.0185343 , 0.01758536, 0.02052227,
#        0.02317089, 0.02235408, 0.01787965, 0.02214988, 0.01794572,
#        0.0337113 , 0.03249211, 0.03408368, 0.03752507, 0.03960912,
#        0.03943495, 0.03879233, 0.04153103, 0.04410756, 0.04702647,
#        0.05174113, 0.06164491, 0.06179505, 0.06730851, 0.07142856,
#        0.06434759, 0.06707427, 0.06702022, 0.07466578, 0.07357869,
#        0.07559067, 0.07920624, 0.08121825, 0.08701398, 0.09123612,
#        0.09245533, 0.09288177, 0.08566265, 0.0839209 , 0.08417917,
#        0.09096589, 0.09287577, 0.09697783, 0.10664737, 0.11954812,
#        0.11713373, 0.11713972, 0.12646695, 0.12938586, 0.12730777,
#        0.12540992, 0.12343396, 0.12999843, 0.1345029 , 0.13638876])]
# [0.13172814323221588]
#
# [array([0.01243228, 0.01375958, 0.01651631, 0.01914091, 0.01873851,
#        0.0196454 , 0.01923099, 0.0185343 , 0.01758536, 0.02052227,
#        0.02317089, 0.02235408, 0.01787965, 0.02214988, 0.01794572,
#        0.0337113 , 0.03249211, 0.03408368, 0.03752507, 0.03960912,
#        0.03943495, 0.03879233, 0.04153103, 0.04410756, 0.04702647,
#        0.05174113, 0.06164491, 0.06179505, 0.06730851, 0.07142856,
#        0.06434759, 0.06707427, 0.06702022, 0.07466578, 0.07357869,
#        0.07559067, 0.07920624, 0.08121825, 0.08701398, 0.09123612,
#        0.09245533, 0.09288177, 0.08566265, 0.0839209 , 0.08417917,
#        0.09096589, 0.09287577, 0.09697783, 0.10664737, 0.11954812,
#        0.11713373, 0.11713972, 0.12646695, 0.12938586, 0.12730777,
#        0.12540992, 0.12343396, 0.12999843, 0.1345029 , 0.13638876]), array([0.01375958, 0.01651631, 0.01914091, 0.01873851, 0.0196454 ,
#        0.01923099, 0.0185343 , 0.01758536, 0.02052227, 0.02317089,
#        0.02235408, 0.01787965, 0.02214988, 0.01794572, 0.0337113 ,
#        0.03249211, 0.03408368, 0.03752507, 0.03960912, 0.03943495,
#        0.03879233, 0.04153103, 0.04410756, 0.04702647, 0.05174113,
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# reshape data
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1550, 60, 1)

# %%
# build LSTM

model = Sequential()
# LSTM(neuron, return_sq=using another layer, input_shape)
model.add(LSTM(50, return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# train model
model.fit(x_train,y_train, batch_size=1, epochs=1)
# Out:
# 1550/1550 [==============================] - 42s 24ms/step - loss: 7.0272e-04

# %%
# creaate testing dataset
# create a new array containing scaled value from index 1543 to 2003

test_data = scaled_data[training_data_len-60:,:]
x_test = []
y_test = dataset[training_data_len:,:]

for i in range (60, len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %%
# convert numpy
x_test = np.array(x_test)

# reshape
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1],1))

# %%
# get model predicted price value

predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get root mean square error
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 1.1251755140314055

# %%
valid = data[training_data_len:]
valid['Predictions'] = predictions
# print(valid)
valid[['Close', 'Predictions']]
# Out:
# <ipython-input-50-3ae3fd5acf8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions
#                 Close  Predictions
# Date
# 2018-05-29  46.974998    45.972012
# 2018-05-30  46.875000    46.011459
# 2018-05-31  46.717499    46.024521
# 2018-06-01  47.560001    46.004116
# 2018-06-04  47.957500    46.094128
# ...               ...          ...
# 2019-12-24  71.067497    68.390320
# 2019-12-26  72.477501    68.667694
# 2019-12-27  72.449997    69.111771
# 2019-12-30  72.879997    69.539009
# 2019-12-31  73.412498    69.960541
#
# [402 rows x 2 columns]

# %%
# plot data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

# visualize data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price',fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
# plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-52-c046ebcd647b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
#  show valid and predicted price
valid
# Out:
#                 Close  Predictions
# Date
# 2018-05-29  46.974998    45.972012
# 2018-05-30  46.875000    46.011459
# 2018-05-31  46.717499    46.024521
# 2018-06-01  47.560001    46.004116
# 2018-06-04  47.957500    46.094128
# ...               ...          ...
# 2019-12-24  71.067497    68.390320
# 2019-12-26  72.477501    68.667694
# 2019-12-27  72.449997    69.111771
# 2019-12-30  72.879997    69.539009
# 2019-12-31  73.412498    69.960541
#
# [402 rows x 2 columns]

# %%
# get the quote

appl_quote =  web.DataReader('AAPL', data_source='yahoo',start='2012-01-01', end='2019-12-20')
new_def = appl_quote.filter(['Close'])
last_60_days = new_def[-60:].values
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test) 
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[68.10357]]

# %%
appl_quote2 =  web.DataReader('AAPL', data_source='yahoo',start='2019-12-11', end='2019-12-21')
print(appl_quote2['Close'])
# Out:
# Date
# 2019-12-10    67.120003
# 2019-12-11    67.692497
# 2019-12-12    67.864998
# 2019-12-13    68.787498
# 2019-12-16    69.964996
# 2019-12-17    70.102501
# 2019-12-18    69.934998
# 2019-12-19    70.004997
# 2019-12-20    69.860001
# Name: Close, dtype: float64
